# %% [markdown]
# <b>In this notebook you will compare six different ML classifiers on COVID-19 data. <b/>
#
# In the first third we will prepare the data and experiments, the middle third build and analyse the visualizations, and the final third explore ideas for improving the models.
#
# <i>If you find opportunites for improvement, don't hesitate to reach out!<i/>

# %%
import imblearn
import imblearn.over_sampling as imbovr
from IPython.display import HTML, display, Image
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sb
import sklearnex
from sklearnex import patch_sklearn
patch_sklearn()
import sklearn.preprocessing as sklp
import sklearn.metrics as sklm
from sklearn.metrics import confusion_matrix
import sklearn.model_selection as sklms
import sklearn.compose as sklcmp
import sklearn.linear_model as lm
import sklearn.discriminant_analysis as da
import sklearn.naive_bayes as nb
import sklearn.neighbors as nbr
import sklearn.tree as tree
import sklearn.svm as svm
import xgboost as xgb
import sklearn.feature_selection as sklfs
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %% [markdown]
# <b>Preparing the Data<b>

# %% [markdown]
# The first step for preparing the data is to load it from the project_data.csv stored in the repo. We select the columns we want to keep and use the proper delimiter + encoding given the data.
#
# <i>The link for public access to this data is available in this repo's README.txt.<i/>

# %%
def load_data(filepath_from_script: str = '\data\project_data.csv'):
    """Load data from csv -- only use columns """
    cols = ("DataNotificacao", "Evolucao", "CriterioConfirmacao", "StatusNotificacao", "FaixaEtaria", "Sexo", "RacaCor",
        "Escolaridade", "Febre", "DificuldadeRespiratoria", "Tosse", "Coriza", "DorGarganta", "Diarreia", "Cefaleia",
        "ComorbidadePulmao", "ComorbidadeCardio", "ComorbidadeRenal", "ComorbidadeDiabetes", "ComorbidadeTabagismo",
        "ComorbidadeObesidade", "FicouInternado", "ViagemBrasil", "ViagemInternacional")
    
    return pd.read_csv(os.getcwd() + filepath_from_script, 
                       delimiter=";",
                       encoding='cp1252',
                       usecols=lambda x: x in cols)  # only loads the required columns from the dataset

# %% [markdown]
# We start the process by only keeping rows with a Status Notification of 'Closed' and Outcome of 'Cured', 'Death by other causes', or 'Death by COVID-19'...

# %%
def filter_df(data):
    """Remove rows with data that will not help analyses"""
    new_data = data[
        data['StatusNotificacao'] == 'Encerrado']

    keep_outcomes = ["Cura", 'Óbito por outras causas', 'Óbito pelo COVID-19']
    new_data = new_data[(new_data['Evolucao'].isin(keep_outcomes))]

    return new_data

# %% [markdown]
# We replace the Portuguese found in the dataset to English for ease-of-use...

# %%
def replace_portuguese(data):
    """Convert Portuguese to English for easier analysis and exploration"""
    # rename column headers
    data.columns = ['NotificationDate', 'Outcome', 'CriteriaConfirmation', 'AgeGroup', 'Sex', 'ColorRace', 'Education',
                    'Fever', 'BreathingDifficulty', 'Cough', 'RunnyNose', 'SoreThroat', 'Diarrhea', 'Headache',
                    'ComorbidityPulmonary', 'ComorbidityCardiac', 'ComorbidityRenal', 'ComorbidityDiabetes',
                    'ComorbiditySmoking', 'ComorbidityObesity', 'Hospitalized', 'TravelBrasil', 'TravelInternational']

    # replace Portuguese with English words, and No or Yes with 0 or 1
    data.replace(
        {"Não": "No", "Sim": "Yes", "I": "N/A", "-": "N/A", "Ignorado": "N/A", "Não se aplica": "N/A",
         "Não Informado": "N/A", "Cura": 0, "Óbito por outras causas": 1, "Preta": "Black", "Branca": "White", 
         "Parda": "Brown", "Indigena": "Indigenous", "Amarela": "Yellow", "Clinico": "Clinic", "Laboratorial": "Lab", 
         "Clinico Epdemiologico": "Epidem.", "Ensino médio completo (antigo colegial ou 2º grau ) ": "HS",
         "No Information": "N/A", "-": "N/A", "5ª à 8ª série incompleta do EF (antigo ginásio ou 1º grau)": "I Gr. 8",
         "4ª série completa do EF (antigo primário ou 1º grau)": "Gr. 4",
         "Ensino médio incompleto (antigo colegial ou 2º grau )": "I HS",
         "1ª a 4ª série incompleta do EF (antigo primário ou 1º grau)": "I Gr. 4",
         "Educação superior incompleta ": "I Higher", "Educação superior completa": "Higher Ed.",
         "Ensino fundamental completo (antigo ginásio ou 1º grau) ": "Gr. 1", "Analfabeto": "None",
         "Óbito pelo COVID-19": 1, "0 a 4 anos": "0-4", "05 a 9 anos": "5-9", "10 a 19 anos": "10-19", 
         "20 a 29 anos": "20-29", "30 a 39 anos": "30-39", "40 a 49 anos": "40-49", "50 a 59 anos": "50-59", 
         "60 a 69 anos": "60-69", "70 a 79 anos": "70-79", "80 a 89 anos": "80-89", "90 anos ou mais": "90+"},
        inplace=True)

# %% [markdown]
# We set each column in the data to be a string...

# %%
def set_dtypes(data):
    """Set dtypes and set missing values for int columns"""
    for i in data.columns:
        data[i].astype(str)

# %% [markdown]
# And we run all these functions together, as well as dropping the Status Notification column after we used it for filtering.

# %%
def clean_data(data):
    """Prepare data for further analysis"""
    new_data = filter_df(data)

    new_data.drop(columns='StatusNotificacao',
                  inplace=True)

    replace_portuguese(new_data)

    set_dtypes(new_data)

    return new_data

# %% [markdown]
# We create a function for creating the values of a new column by adding 1 if the value of the columns to sum are "Yes"...

# %%
def sum_true_columns(data, new_col: object, cols_to_sum: list):
    """Adds columns from cols_to_sum that are equal to 1 (i.e. true) and avoids missing values and 0s"""
    data[new_col] = 0
    for i in cols_to_sum:
        data[new_col] += data[i] == "Yes"

# %% [markdown]
# And use it for creating two summary variables -- Sum of Comorbidites and Sum of Symptoms. On top of these, we create a generic Over60 variable that takes values Yes or No.

# %%
def add_summary_variables(data):
    """Add new variables -- sum of comorbidities, sum of symptoms"""

    # create sum of comorbidities and symptoms, and for each, add 1 if the column at that row is equal to 1 (is true)
    sum_true_columns(data,
                     new_col='SumComorbidities',
                     cols_to_sum=['ComorbidityPulmonary', 'ComorbidityCardiac', 'ComorbidityRenal',
                                  'ComorbidityDiabetes', 'ComorbiditySmoking', 'ComorbidityObesity'])

    sum_true_columns(data,
                     new_col='SumSymptoms',
                     cols_to_sum=['Fever', 'BreathingDifficulty', 'Cough', 'RunnyNose',
                                  'SoreThroat', 'Diarrhea', 'Headache'])

    # create new column if first two characters of that row's AgeGroup (as an int) is greater than or equal to 60
    over60_ages = ['60-69', '70-79', '80-89', '90+']
    data['OverSixty'] = np.where(data['AgeGroup'].isin(over60_ages), "Yes", "No")

# %% [markdown]
# Lastly, we split the data into two sets:
#
# Experiment 1: February 28, 2020 --> May 23, 2020.
#
# Experiment 2: May 24, 2020 --> May 31, 2020.

# %%
def create_exp_datasets(all_data):
    """Split datasets for analyses matching the paper's datasets"""
    # create exp_1
    exp1 = all_data[
        (all_data['NotificationDate'] < "2020-05-24") & (all_data['NotificationDate'] > "2020-02-28")].copy()

    # create exp2 dataset (May 24 - May 31)
    exp2 = all_data[
        (all_data['NotificationDate'] < "2020-06-01") & (all_data['NotificationDate'] > "2020-05-23")].copy()

    return exp1, exp2

# %% [markdown]
# We use this main function to run all of our cleaning functions neatly.
#
# The experiment will return our datasets for Exp1, Exp2, and also a set of all the data kept together for future use. A few rows of the Exp1 data are below.

# %%
def main_cln():
    """Run overarching functions"""
    df = load_data()

    df = clean_data(df)

    add_summary_variables(df)

    exp1, exp2 = create_exp_datasets(df)

    for d in exp1, exp2:
        del d['NotificationDate']

    return exp1, exp2, df

# %%
# ------ Clean the Data and build Test / Training sets for each Exp
# # creates a df for each experiment, in one list called dfs, from the main() method in cleaning module
pr10_exp1_df, pr10_exp2_df, all_data = main_cln()
dfs = [pr10_exp1_df, pr10_exp2_df, all_data]

pr10_exp1_df.head(5)
# Out:
#          Outcome CriteriaConfirmation AgeGroup Sex ColorRace Education Fever  \
# 1122132        0                  Lab    40-49   F     Black        HS    No
# 1122137        0                  Lab    30-39   M     White        HS    No
# 1122138        0                  Lab    30-39   M       N/A       N/A   Yes
# 1122139        0                  Lab    40-49   F     White   I Gr. 8    No
# 1122146        0                  Lab    20-29   M     Brown       N/A   N/A
#
#         BreathingDifficulty Cough RunnyNose  ... ComorbidityRenal  \
# 1122132                  No   Yes       Yes  ...               No
# 1122137                  No   Yes        No  ...               No
# 1122138                  No   Yes        No  ...               No
# 1122139                  No    No        No  ...               No
# 1122146                 N/A   N/A       N/A  ...              N/A
#
#         ComorbidityDiabetes ComorbiditySmoking ComorbidityObesity  \
# 1122132                  No                 No                 No
# 1122137                  No                 No                 No
# 1122138                  No                 No                 No
# 1122139                  No                 No                 No
# 1122146                 N/A                N/A                N/A
#
#         Hospitalized TravelBrasil TravelInternational SumComorbidities  \
# 1122132           No           No                  No                0
# 1122137           No           No                  No                0
# 1122138           No           No                  No                1
# 1122139          N/A           No                  No                0
# 1122146          N/A          N/A                 N/A                0
#
#         SumSymptoms OverSixty
# 1122132           2        No
# 1122137           2        No
# 1122138           2        No
# 1122139           1        No
# 1122146           0        No
#
# [5 rows x 25 columns]

# %% [markdown]
# <b> Experiment Functions <b>

# %% [markdown]
# Now that the data is cleaned and ready, we can get into reproducing the paper's findings.
#
# The paper ran two different experiments, each on different weeks of the same dataset.
#
# Below is a graphic from the paper describing the process for Experiment 1.

# %%
display(Image(filename=f'{os.getcwd()}\\figures\\paper_exp1_repr.PNG'))

# %% [markdown]
# We first need to write a function for encoding our categorical variables.
#
# If they are not ordered (like ColorRace), we use the OneHotEncoder which assigns variables as they are seen in the data.
#
# If they are ordered (like AgeGroup), we provide levels (order) for the variable and use the OrdinalEncoder.
#
# Lastly due to the large imbalance in our dataset (6-8% are deaths, the remaining 92-94% are all cured cases), we use random oversampling to balance the data. We use a sampling strategy value of 1 which creates an equal number of death and cured cases. This will vastly improve the learning of our models.

# %%
def preprocessing_fns(focused=False):
    """Build pipeline of transformation and oversampling for balancing"""
    categorical_encoder = sklp.OneHotEncoder(sparse_output=False, handle_unknown='ignore')

    agegroup_levels = ['0-4', '5-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80-89', '90+']
    sumcom_levels = [0, 1, 2, 3, 4, 5, 6]
    sumsym_levels = [0, 1, 2, 3, 4, 5, 6, 7]

    ordinal_encoder = sklp.OrdinalEncoder(handle_unknown='use_encoded_value',
                                                       unknown_value=-1,
                                                       categories=[agegroup_levels, sumcom_levels, sumsym_levels])

    if not focused:    
        categorical_fts = ['CriteriaConfirmation', 'Sex', 'ColorRace', 'Education', 'Fever',
                           'BreathingDifficulty', 'Cough', 'RunnyNose', 'SoreThroat', 'Diarrhea', 'Headache',
                           'ComorbidityPulmonary', 'ComorbidityCardiac', 'ComorbidityRenal', 'ComorbidityDiabetes',
                           'ComorbiditySmoking', 'ComorbidityObesity', 'Hospitalized', 'TravelBrasil',
                           'TravelInternational', 'OverSixty']
    
    # this option is for when we reduce the dimensionality (# of features) of the data further in the notebook
    else:
        categorical_fts = ['Education', 'BreathingDifficulty', 'SoreThroat', 'Headache', 'ComorbidityDiabetes',
                           'Hospitalized', 'OverSixty']
        
    ordinal_fts = ['AgeGroup', 'SumComorbidities', 'SumSymptoms']
    transformer = sklcmp.make_column_transformer((categorical_encoder, categorical_fts),
                                                 (ordinal_encoder, ordinal_fts))

    oversampler = imbovr.RandomOverSampler(sampling_strategy=1)

    return transformer, oversampler

# %% [markdown]
# Here we build our function for cross validation, which includes creating our pipeline for steps our data should take before processing and the inputs for cross validation. We also output the raw prediction values and real outcomes.

# %%
def x_validate(model, features, target, evals: list, focused=False):
    """Run test w/ stratified 10-fold cross-validation"""

    transformer, oversampler = preprocessing_fns() if not focused else preprocessing_fns(focused=True)

    pipeline = imblearn.pipeline.make_pipeline(transformer, oversampler, model)

    pipeline.fit(features, target)

    split_method = sklms.StratifiedKFold(n_splits=10)


    output_all = sklms.cross_validate(estimator=pipeline,
                                                    X=features,
                                                    y=target,
                                                    scoring=evals,
                                                    cv=split_method,
                                                    n_jobs=-1)  # uses multiple processors for training
    print(f'{model} results done')


    target_predictions = sklms.cross_val_predict(estimator=pipeline,
                                                               X=features,
                                                               y=target,
                                                               cv=split_method,
                                                               n_jobs=-1)
    print(f'{model} predicts done')

    target_preds_real = [target_predictions.ravel(), target.values.ravel()]


    return output_all, target_preds_real

# %% [markdown]
# This function is used only for training our models and outputs our training scores.

# %%
def train_models(models, features, target, evals: list, focused=False):
    """Runs all algos on the given dataset(s) and returns all outputs as a list"""

    outputs = []
    
    for model in models:
        results, target_preds_real = x_validate(model, features, target, evals, focused)
        
        preds, real = target_preds_real
        
        output = {
            'Model': model,
            'Accuracy': np.mean(results['test_accuracy']),
            'ROC AUC': np.mean(results['test_roc_auc']),
            'Average Precision': np.mean(results['test_average_precision']),
            'Precision': np.mean(results['test_precision']),
            'Recall': np.mean(results['test_recall']),
            'F1': np.mean(results['test_f1']),
            'Predictions': preds,
            'Real Outcomes': real
        }
        
        outputs.append(output)

    return outputs

# %% [markdown]
# And this function is used for training on training data then, as the name suggests, testing on the test data.
#
# Again we build a pipeline, but then use <i>pipeline.predict(test_features)</i> after fitting the pipeline to generate predictions for creating our metrics.

# %%
def test_models(models, train_features, train_target, test_features, test_target, focused):
    """Test the models on the given data"""
    
    transformer, oversampler = preprocessing_fns() if not focused else preprocessing_fns(focused=True)

    test_results = []

    for model in models:
        pipeline = imblearn.pipeline.make_pipeline(transformer, oversampler, model)

        pipeline.fit(train_features, train_target)

        preds = pipeline.predict(test_features)
        real = test_target.values

        probs = pipeline.predict_proba(test_features)[:, 1]
        precision, recall, _ = sklm.precision_recall_curve(real, probs)

        result = {
            'Model': model,
            'Accuracy': sklm.accuracy_score(real, preds),
            'ROC AUC': sklm.roc_auc_score(real, preds),
            'Average Precision': sklm.average_precision_score(real, probs),
            'Precision': sklm.precision_score(real, preds),
            'Recall': sklm.recall_score(real, preds),
            'F1': sklm.f1_score(real, preds),
            'Predictions': preds,
            'Real Outcomes': real
        }
        test_results.append(result)

    return test_results

# %% [markdown]
# We put all our training and testing functions together to create one function that will run an experiment for us. We can use the rpt parameter to change the number of times we want to run an experiment (33x for exp1, or 1x for exp2).

# %%
def run_exp(models, train_features, train_target, test_features, test_target, evals, rpt: int = 33, focused=False):
    """Train and test the models given the inputs"""
    train_all = []
    test_all = []
    for num in range(rpt):
        train_results = train_models(models, train_features, train_target, evals, focused)

        test_results = test_models(models, train_features, train_target, test_features, test_target, focused)

        train_all.append(train_results)
        test_all.append(test_results)

        print(f'Round {num + 1} completed')

    return [train_all, test_all]

# %% [markdown]
# Now that the main function for our experiment is completed, we can build the train and test sets for our first experiment.

# %%
# ------- EXP1 ------
# # creates the exp1 train/test datasets
exp1_features = pr10_exp1_df.iloc[:, 1:]
exp1_targets = pr10_exp1_df.iloc[:, 0]
exp1_f_train, exp1_f_test, exp1_t_train, exp1_t_test = sklms.train_test_split(
    exp1_features,
    exp1_targets,
    train_size=0.7,          # creates 70% of data for training, and 30% of data for validating
    stratify=exp1_targets)   # maintains same distribution of target variable values in train and test data

# %% [markdown]
# Next up is tuning the parameters and hyperparameters for the models to optimize performance...

# %%
def grid_search(models_and_param_grid, features, target, eval, verbose: int = 0):
    """Test all given parameters to find the best-performing model"""
    for model in models_and_param_grid:
        transformer, oversampler = preprocessing_fns()

        pipeline = imblearn.pipeline.Pipeline(steps=[('transformer', transformer),
                                                        ('oversampler', oversampler),
                                                        ('model', model[0])])

        split_method = sklms.StratifiedKFold(n_splits=10)

        gs = sklms.GridSearchCV(estimator=pipeline,
                                   param_grid=model[1],
                                   scoring=eval,
                                   n_jobs=-1,
                                   cv=split_method,
                                   refit=True,
                                   verbose=verbose)

        gs.fit(features, target)

        return gs.best_params_, pd.DataFrame(gs.cv_results_)

# %%
# # Grid Search to find the best Hyperparameters
params, results = grid_search([[lm.LogisticRegression(),
                                    [{"model__max_iter": (1000, 1500),
                                      "model__C": (2, 3)}]]],
                                  features=exp1_f_train,
                                  target=exp1_t_train,
                                  eval='roc_auc',
                                  verbose=3)

params
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# {'model__C': 2, 'model__max_iter': 1000}

# %% [markdown]
# And using the grid search function for each model, we can determine the most effective parameters and hyperparameters for each model given the metric we optimized on previously (ROC AUC).

# %%
# set the tuned models to test for the experiments
tuned_models = [
    lm.LogisticRegression(max_iter=1500, C=2.0, fit_intercept=True, tol=1e-05),
    da.LinearDiscriminantAnalysis(store_covariance=True),
    nbr.KNeighborsClassifier(algorithm='kd_tree', leaf_size=10, n_neighbors=10, p=1),
    tree.DecisionTreeClassifier(max_features=None, max_leaf_nodes=10, class_weight='balanced',
                                criterion='log_loss', min_samples_leaf=3),
    xgb.XGBClassifier(colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.6),
    svm.SVC(kernel='rbf', C=10, gamma=0.0001, probability=True)]

# %% [markdown]
# The authors repeated the first experiment 33x and took the average of the results.
#
# After running an experiment X number of times, we will end up with X scores for each model tested. The below function converts this into a list of mean scores for each model.

# %%
def lists_of_runs_to_lists_of_model_means(all_dfs: list):
    """Convert list of dictionaries of each run into one list of dictionaries of average results for each model"""
    all_mean_results = []
    for data in all_dfs:
        data_by_model = []
        run_num = 0

        for run in data:
            run_num += 1
            for new_model_run in run:
                if new_model_run.get('Model') in [model_runs.get('Model') for model_runs in data_by_model]:
                    for existing in data_by_model:
                        if new_model_run.get('Model') == existing.get('Model'):
                            for key in existing.keys():
                                if key not in ('Model', 'Predictions', 'Real Outcomes'):
                                    existing[key] += new_model_run[key]
                            for key in ('Predictions', 'Real Outcomes'):
                                existing[key] = np.append(existing[key], new_model_run[key])
                else:
                    data_by_model.append(new_model_run)

        # divide by number of runs
        for model in data_by_model:
            for key in model.keys():
                if key not in ('Model', 'Predictions', 'Real Outcomes'):
                    model[key] = model[key] / run_num

        all_mean_results.append(data_by_model)

    return all_mean_results

# %% [markdown]
# Given the time it takes to run the experiment 33x, I changed it to only run 1x in this notebook so you can more quickly view the results. In the repository, figures are saved from when I ran the experiment 33x. Feel free to adjust this number and see how the results change.
#
# Since we only repeated the experiment once the last line of code is not required, but is critical if you repeat the experiment more than once.

# %%
# Run Experiment 1 and create Training and Test Results
all_exp1_dfs = run_exp(tuned_models,
                       train_features=exp1_f_train,
                       train_target=exp1_t_train,
                       test_features=exp1_f_test,
                       test_target=exp1_t_test,
                       evals=['accuracy', 'roc_auc', 'average_precision', 'precision', 'recall', 'f1'],
                       rpt=1)

# Get means of test results for each run
exp1_train_means, exp1_test_means = lists_of_runs_to_lists_of_model_means(all_exp1_dfs)
# Out:
# LogisticRegression(C=2.0, max_iter=1500, tol=1e-05) results done
# LogisticRegression(C=2.0, max_iter=1500, tol=1e-05) predicts done
# LinearDiscriminantAnalysis(store_covariance=True) results done
# LinearDiscriminantAnalysis(store_covariance=True) predicts done
# KNeighborsClassifier(algorithm='kd_tree', leaf_size=10, n_neighbors=10, p=1) results done
# KNeighborsClassifier(algorithm='kd_tree', leaf_size=10, n_neighbors=10, p=1) predicts done
# DecisionTreeClassifier(class_weight='balanced', criterion='log_loss',
#                        max_leaf_nodes=10, min_samples_leaf=3) results done
# DecisionTreeClassifier(class_weight='balanced', criterion='log_loss',
#                        max_leaf_nodes=10, min_samples_leaf=3) predicts done
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...) results done
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...) predicts done
# SVC(C=10, gamma=0.0001, probability=True) results done
# SVC(C=10, gamma=0.0001, probability=True) predicts done
# Round 1 completed

# %% [markdown]
# The second experiment was identical to the first experiment except the train data was temporally-different from the test data and it ran only 1x instead of 33x.

# %%
display(Image(filename=f'{os.getcwd()}\\figures\\paper_exp2_repr.PNG'))

# %% [markdown]
# Repeating the same process as above, we first create the train and test sets.
#
# We use the features + targets from Exp1 as our train set, and the May 24 - May 31 data as our test set...

# %%
# -------- EXP2 -------
# creates the exp2 train/test datasets
exp2_f_train = pr10_exp1_df.iloc[:, 1:]
exp2_t_train = pr10_exp1_df.iloc[:, 0]
exp2_f_test = pr10_exp2_df.iloc[:, 1:]
exp2_t_test = pr10_exp2_df.iloc[:, 0]

# %% [markdown]
# Then we run the experiment once for Experiment 2.

# %%
# Run Experiment 2 and create Training and Test Results
all_exp2_dfs = run_exp(tuned_models,
                       exp2_f_train,
                       exp2_t_train,
                       exp2_f_test,
                       exp2_t_test,
                       evals=['accuracy', 'roc_auc', 'average_precision', 'precision', 'recall', 'f1'],
                       rpt=1)

# Get means of test results for each run
exp2_train_means, exp2_test_means = lists_of_runs_to_lists_of_model_means(all_exp2_dfs)
# Out:
# LogisticRegression(C=2.0, max_iter=1500, tol=1e-05) results done
# LogisticRegression(C=2.0, max_iter=1500, tol=1e-05) predicts done
# LinearDiscriminantAnalysis(store_covariance=True) results done
# LinearDiscriminantAnalysis(store_covariance=True) predicts done
# KNeighborsClassifier(algorithm='kd_tree', leaf_size=10, n_neighbors=10, p=1) results done
# KNeighborsClassifier(algorithm='kd_tree', leaf_size=10, n_neighbors=10, p=1) predicts done
# DecisionTreeClassifier(class_weight='balanced', criterion='log_loss',
#                        max_leaf_nodes=10, min_samples_leaf=3) results done
# DecisionTreeClassifier(class_weight='balanced', criterion='log_loss',
#                        max_leaf_nodes=10, min_samples_leaf=3) predicts done
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...) results done
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...) predicts done
# SVC(C=10, gamma=0.0001, probability=True) results done
# SVC(C=10, gamma=0.0001, probability=True) predicts done
# Round 1 completed

# %% [markdown]
# <b>Visualizations<b>

# %% [markdown]
# The next step is analysing the demographics of the data and comparing the models.
#
# We first set some configurations/variables for future use...

# %%
# prevent Jupyter notebook from displaying plot when it is made
plt.ioff()

# set display theme to basic seaborn
sb.set_theme()

# set figure directory
figure_path = os.getcwd() + "\\figures"      # for saving files locally and showing figures

# %% [markdown]
# And create a small function for adding spaces in strings without spaces -- important for cleaning up the names of our models.

# %%
def add_spaces(i):
    """Add spaces before every uppercase letter after the first letter in the word"""
    string = [i[0], ]
    for letter in i[1:]:
        if letter.isupper():
            string.append(f" {letter}")
        else:
            string.append(letter)
    return ''.join(string)

# %% [markdown]
# All of our visualizations are going to become a grid of subplots to explore data across different parameters, models, and/or metrics. As a result, we will first build the plot by itself, then combine them into a grid.
#
# First, we build a countplot for exploring the demographics of the data:

# %%
def histo_bar_plot(df, parameter: str, grouping: str = 'Outcome', axis=None):
    """Create a histogram of counts of each parameter for each group"""
    # set as categorical variable, sorted from highest to lowest count
    df[parameter] = pd.Categorical(df[parameter], categories=df[parameter].value_counts().index)

    # build plot
    plot = sb.countplot(data=df,
                        x=parameter,
                        hue=grouping,
                        ax=axis)

    # make xlabel by adding space before second (or greater) capital letter(s) in parameter name
    xlabel = add_spaces(parameter)

    # remove count from ylabel, set xlabel as the item in xlabels list at same item as current parameter
    plot.set(ylabel=None, xlabel=xlabel)

# %% [markdown]
# Then create the function that will combine multiple plots into one figure:

# %%
def build_plot_grid(df, parameters: list, grouping: str = 'Outcome', filename: str = 'test', title: str = "", w: int = 3):
    """Build a grid of histogram plots"""
    h = len(parameters) // w if len(parameters) % w == 0 else len(parameters) // w + 1
    figure, grid = plt.subplots(h, 3, figsize=(15, 10))
    figure.suptitle(title)

    row, col = 0, 0

    for var in parameters:
        if not h == 1:
            histo_bar_plot(df, parameter=var, grouping=grouping, axis=grid[row, col])
            if [row, col] != [0, 0]:
                grid[row, col].get_legend().remove()
        else:
            histo_bar_plot(df, parameter=var, grouping=grouping, axis=grid[col])
            if [col] != [0]:
                grid[col].get_legend().remove()

        # if the sum of characters in all the x tick labels is >20, rotate the labels to avoid overlapping
        sum_tick_chars = 0
        for value in df[var].value_counts().index:
            sum_tick_chars += len(str(value))
        if sum_tick_chars > 20:
            plt.setp(grid[row, col].get_xticklabels(), rotation=45,
                     horizontalalignment='right', rotation_mode='anchor')

        # after adding the plot, move to the next grid in the figure
        if not col == w - 1:
            col += 1
        else:
            col, row = 0, row + 1

        # clear the axes of all plots after the last column index to avoid empty axes
        last_col_ind = len(parameters) % w - 1
        if last_col_ind >= 0:
            for i in range(last_col_ind + 1, w):
                if h > 1:
                    grid[h - 1, i].set_axis_off()
                else:
                    grid[i].set_axis_off()

    plt.tight_layout()

# %% [markdown]
# And then create a function for building multiple grids of countplots at once. This function will produce a figure of the distribution of cured vs death outcomes by descriptor variable, symptom, and comorbidity. You can see the outputs a few cells below.

# %%
def build_all_demographics(df, name):
    """Build and show (or save) multiple histogram plot grids"""
    build_plot_grid(df=df,
                    parameters=['CriteriaConfirmation', 'AgeGroup', 'Education', 'ColorRace', 'Sex', 'OverSixty',
                                'Hospitalized', 'TravelBrasil', 'TravelInternational', 'SumSymptoms',
                                'SumComorbidities'],
                    filename=f"{name}_descriptors",
                    title=f'{name} Descriptors')
    
    plt.show()

    build_plot_grid(df=df,
                    parameters=['Fever', 'BreathingDifficulty', 'Cough', 'RunnyNose', 'SoreThroat', 'Diarrhea',
                                'Headache'],
                    filename=f"{name}_symptoms",
                    title=f'{name} Symptoms')
    
    plt.show()

    build_plot_grid(df=df,
                    parameters=['ComorbidityPulmonary', 'ComorbidityCardiac', 'ComorbidityRenal',
                                'ComorbidityDiabetes', 'ComorbiditySmoking', 'ComorbidityObesity'],
                    filename=f"{name}_comorbidities",
                    title=f'{name} Comorbidities')
    
    plt.show()

# %% [markdown]
# And we run the function on the Experiment 1 and Experiment 2 data to explore some relationships at a basic level:

# %%
# create and save demographics data for each experiment
data_names = ['Experiment 1', 'Experiment 2']

for data_w_name in zip(dfs, data_names):
    build_all_demographics(data_w_name[0], data_w_name[1])

# %% [markdown]
# We next start to work on building confusion matrices to better understand how our models are performing.
#
# We will take a similar process to before: build a figure --> build a grid. But this time, we need to prepare our data before producing a confusion matrix.
#
# The below function uses all the provided data and returns a list of model names and their predictions + real outcomes from the experiments:

# %%
def create_confusion_matrix_info(data):
    """Prepare real outcomes and predictions data for each model into a format for the confusion matrix"""
    all_models = [type(model).__name__ for model in [d['Model'] for d in data]]
    all_real_and_preds = []
    for d in data:
        real_and_preds = [[], []]
        real_and_preds[0] = d['Real Outcomes']
        real_and_preds[1] = d['Predictions']
        all_real_and_preds.append(real_and_preds)

    return all_models, all_real_and_preds

# %% [markdown]
# Then we can use the output to build a confusion matrix:

# %%
def build_confusion_matrix(model, real, preds, axis=None):
    """Create a confusion matrix"""
    mtrx = confusion_matrix(real, preds)
    htmp = sb.heatmap(mtrx / np.sum(mtrx), annot=True, fmt='.1%', cmap='Reds', ax=axis)

    htmp.set_xlabel('Predictions')
    htmp.xaxis.set_ticklabels(['Cured', 'Death'])

    htmp.set_ylabel('Real Outcomes')
    htmp.yaxis.set_ticklabels(['Cured', 'Death'])

    htmp.set_title(f'{model}')

# %% [markdown]
# And then we can build a grid of confusion matrices, one for each model:

# %%
def build_conf_mtrx_grid(models: list, all_real_and_preds: list, filename: str, title: str = '', w: int = 3):
    """Make a grid of confusion matrices"""
    h = len(all_real_and_preds) // w if len(all_real_and_preds) % w == 0 else len(all_real_and_preds) // w + 1
    figure, grid = plt.subplots(h, 3, figsize=(15, 8))
    figure.suptitle(title)

    row, col = 0, 0

    for i in range(len(all_real_and_preds)):
        if not h == 1:
            build_confusion_matrix(models[i], all_real_and_preds[i][0], all_real_and_preds[i][1], axis=grid[row, col])

        else:
            build_confusion_matrix(models[i], all_real_and_preds[i][0], all_real_and_preds[i][1], axis=grid[col])

        if not col == w - 1:
            col += 1
        else:
            col, row = 0, row + 1

        last_col_ind = len(all_real_and_preds) % w - 1
        if last_col_ind >= 0:
            for i in range(last_col_ind + 1, w):
                if h > 1:
                    grid[h - 1, i].set_axis_off()
                else:
                    grid[i].set_axis_off()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# And finally we will view a confusion matrix for each model from the Experiment 2 test data.
#
# But before the results, take a second to think: which of the options below would you optimize for a model predicting COVID outcomes?
# 1) Maximizing accurate predictions of who will get cured
# 2) Maximizing accurate predictions of who is at high-risk
# 3) Reducing the error predictions of who will get cured
# 4) Reducing the error predictions of who is at high-risk

# %%
# create correct data format for confusion matrices
all_exp2_test_models, all_exp2_test_real_and_preds = create_confusion_matrix_info(exp2_test_means)

# create grid of confusion matrices
build_conf_mtrx_grid(all_exp2_test_models, all_exp2_test_real_and_preds,
                         filename='conf_mtrx_exp2_test',
                         title='Confusion Matrices from Exp2 Test Data')

# %% [markdown]
# An important metric to optimize in this case, for me, is reducing the number of False Negatives. Here that would be reducing the number of times the model predicts a person is Cured (i.e. not at high-risk) but they actually are high-risk.
#
# XGB and SVC have similar False Negative percentages, but XGB has a lower False Positive percentage and so I would select it as our best model.
#
# For comparison's sake, you can look at the confusion matrices from the original paper below.

# %%
display(Image(filename=f'{os.getcwd()}\\figures\\conf_mtrx_paper.PNG'))

# %% [markdown]
# Our last major visualization will be a plot of each model's score across several metrics the paper used -- Accuracy, ROC AUC, PR AUC, Precision, Recall, and F1 score. We can then compare the performance of this notebook's models to the paper's models.
#
# As before, we first create a singular plot:

# %%
def model_metric_bar_plot(data, metric, axis=None):
    """Create a bar plot for a metric of the given models"""
    
    model_shortform = {'LogisticRegression': 'LogReg',
                   'LinearDiscriminantAnalysis': 'LDA',
                   'KNeighborsClassifier': 'KNN',
                   'DecisionTreeClassifier': 'DT',
                   'XGBClassifier': 'XGB',
                   'SVC': 'SVC'}
    models = []
    metric_list = []
    for dat in data:
        models.append(model_shortform.get(str(type(dat['Model']).__name__)))
        metric_list.append(dat[metric])

    df = pd.DataFrame(zip(models, metric_list),
                      columns=['Model', metric])

    bp = sb.barplot(x='Model',
                    y=metric,
                    data=df,
                    ax=axis)

    bp.set_ylabel(None)
    bp.set_xlabel(f'Mean {metric}')
    bp.set_ylim(.2, 1)

# %% [markdown]
# Add multiple plots into a grid:

# %%
def model_metric_bar_grid(data, metrics: list, filename: str, title: str='', w: int=3):
    """Create a grid of the metrics for the given models"""
    h = len(metrics) // w if len(metrics) % w == 0 else len(metrics) // w + 1
    figure, grid = plt.subplots(h, 3, figsize=(15, 10))
    figure.suptitle(title)

    row, col = 0, 0

    for i in range(len(metrics)):
        if h > 1:
            model_metric_bar_plot(data, metrics[i], axis=grid[row, col])
        else:
            model_metric_bar_plot(data, metrics[i], axis=grid[col])

        if not col == w - 1:
            col += 1
        else:
            col, row = 0, row + 1

        last_col_ind = len(metrics) % w - 1
        if last_col_ind >= 0:
            for x in range(last_col_ind + 1, w):
                if h > 1:
                    grid[h - 1, x].set_axis_off()
                else:
                    grid[x].set_axis_off()

    plt.tight_layout()

# %% [markdown]
# And then create the visualizations. We will look at metrics for the train and test results for both Experiment 1 and 2.

# %%
# Barplots of Model Results in each Phase (Baseline, Training, Test) for each Exp, for Acc / ROC AUC / PR AUC
barplot_metrics = ['Accuracy', 'ROC AUC', 'Average Precision', 'Precision', 'Recall', 'F1']

# set data, filename, and title for the barplot images
barplot_info = [
    [exp1_train_means, 'model_metrics_exp1_train', 'Exp1 Training Model Metrics'],
    [exp1_test_means, 'model_metrics_exp1_test', 'Exp1 Test Model Metrics'],
    [exp2_train_means, 'model_metrics_exp2_train', 'Exp2 Training Model Metrics'],
    [exp2_test_means, 'model_metrics_exp2_test', 'Exp2 Test Model Metrics']]

# create  a barplot for each list in barplot_info
for info in barplot_info:
    model_metric_bar_grid(data=info[0], metrics=barplot_metrics, filename=info[1], title=info[2])
    plt.show()

# %% [markdown]
# And here you can compare to the results from the paper:

# %%
display(Image(filename=f'{figure_path}\\paper_exp1_train_results.PNG'))

# %%
display(Image(filename=f'{figure_path}\\paper_exp1_test_results.PNG'))

# %% [markdown]
# If you prefer to look at the numbers directly, we can create a dataframe of the scores for each model and output a table for easy viewing:

# %%
from IPython.display import HTML
def build_comparison_tables(data):
    """Build a table showing the average values of the key metrics for each inputted model"""
    all_metrics = ['Accuracy', 'ROC AUC', 'PR AUC', 'Precision', 'Recall', 'F1']
    all_models = [type(model).__name__ for model in [d['Model'] for d in data]]
    all_acc = [d['Accuracy'] for d in data]
    all_roc = [d['ROC AUC'] for d in data]
    all_avg_prc = [d['Average Precision'] for d in data]
    all_prc = [d['Precision'] for d in data]
    all_rcl = [d['Recall'] for d in data]
    all_F1 = [d['F1'] for d in data]

    df = pd.DataFrame(data=[all_acc, all_roc, all_avg_prc, all_prc, all_rcl, all_F1], columns=all_models)

    df.insert(loc=0, column='', value=pd.Series(all_metrics))
    
    return HTML(pd.DataFrame.to_html(df, index=False))

# %%
build_comparison_tables(exp2_train_means)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LogisticRegression</th>
#       <th>LinearDiscriminantAnalysis</th>
#       <th>KNeighborsClassifier</th>
#       <th>DecisionTreeClassifier</th>
#       <th>XGBClassifier</th>
#       <th>SVC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Accuracy</td>
#       <td>0.884214</td>
#       <td>0.888143</td>
#       <td>0.886271</td>
#       <td>0.884465</td>
#       <td>0.886770</td>
#       <td>0.873552</td>
#     </tr>
#     <tr>
#       <td>ROC AUC</td>
#       <td>0.940226</td>
#       <td>0.938774</td>
#       <td>0.869672</td>
#       <td>0.912821</td>
#       <td>0.943639</td>
#       <td>0.938063</td>
#     </tr>
#     <tr>
#       <td>PR AUC</td>
#       <td>0.643176</td>
#       <td>0.640929</td>
#       <td>0.409496</td>
#       <td>0.524299</td>
#       <td>0.663955</td>
#       <td>0.641025</td>
#     </tr>
#     <tr>
#       <td>Precision</td>
#       <td>0.393309</td>
#       <td>0.401508</td>
#       <td>0.379552</td>
#       <td>0.401018</td>
#       <td>0.399026</td>
#       <td>0.369851</td>
#     </tr>
#     <tr>
#       <td>Recall</td>
#       <td>0.873665</td>
#       <td>0.857574</td>
#       <td>0.724852</td>
#       <td>0.813381</td>
#       <td>0.872890</td>
#       <td>0.869677</td>
#     </tr>
#     <tr>
#       <td>F1</td>
#       <td>0.541158</td>
#       <td>0.545486</td>
#       <td>0.497483</td>
#       <td>0.531187</td>
#       <td>0.546403</td>
#       <td>0.517969</td>
#     </tr>
#   </tbody>
# </table>

# %%
build_comparison_tables(exp2_test_means)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LogisticRegression</th>
#       <th>LinearDiscriminantAnalysis</th>
#       <th>KNeighborsClassifier</th>
#       <th>DecisionTreeClassifier</th>
#       <th>XGBClassifier</th>
#       <th>SVC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Accuracy</td>
#       <td>0.876923</td>
#       <td>0.877875</td>
#       <td>0.886281</td>
#       <td>0.834734</td>
#       <td>0.876606</td>
#       <td>0.860270</td>
#     </tr>
#     <tr>
#       <td>ROC AUC</td>
#       <td>0.875726</td>
#       <td>0.872640</td>
#       <td>0.825627</td>
#       <td>0.852043</td>
#       <td>0.880347</td>
#       <td>0.872837</td>
#     </tr>
#     <tr>
#       <td>PR AUC</td>
#       <td>0.644674</td>
#       <td>0.629329</td>
#       <td>0.369150</td>
#       <td>0.535101</td>
#       <td>0.660909</td>
#       <td>0.634538</td>
#     </tr>
#     <tr>
#       <td>Precision</td>
#       <td>0.319288</td>
#       <td>0.320076</td>
#       <td>0.321701</td>
#       <td>0.255255</td>
#       <td>0.320037</td>
#       <td>0.292477</td>
#     </tr>
#     <tr>
#       <td>Recall</td>
#       <td>0.874359</td>
#       <td>0.866667</td>
#       <td>0.756410</td>
#       <td>0.871795</td>
#       <td>0.884615</td>
#       <td>0.887179</td>
#     </tr>
#     <tr>
#       <td>F1</td>
#       <td>0.467764</td>
#       <td>0.467497</td>
#       <td>0.451415</td>
#       <td>0.394890</td>
#       <td>0.470027</td>
#       <td>0.439924</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# And here are the performance metrics from the paper's second experiment:

# %%
display(Image(filename=f'{figure_path}\\performance_tables_paper.PNG'))

# %% [markdown]
# <b>Case Outcomes Moving Into 2021<b/>

# %% [markdown]
# This is the end of replicating the paper, and now we will explore ideas for improving the effectiveness of our models.
#
# But before diving in, let's look at how the proportion of outcomes (cured vs death) changed from the first two months of data in the dataset (Feb - May 2020) compared to the cases from 2021.

# %%
# Show the demographics from the Experiment 1 dataset (first months of the data)
data_names = ['Before May 24, 2020']
data = [pr10_exp1_df]

for data_w_name in zip(data, data_names):
    print(data_w_name[1])
    build_plot_grid(df=data_w_name[0],
                parameters=['Fever', 'BreathingDifficulty', 'Cough', 'RunnyNose', 'SoreThroat', 'Diarrhea',
                            'Headache'],
                filename=f"{data_w_name[1]}_symptoms",
                title='Symptoms in Training Set')
    plt.show()
# Out:
# Before May 24, 2020

# %%
# show the demographics from all the data
data_names = ['2020 and 2021']
data = [all_data]

for data_w_name in zip(data, data_names):
    print(data_w_name[1])
    build_plot_grid(df=data_w_name[0],
                parameters=['Fever', 'BreathingDifficulty', 'Cough', 'RunnyNose', 'SoreThroat', 'Diarrhea',
                            'Headache'],
                filename=f"{data_w_name[1]}_symptoms",
                title='Symptoms in Training Set')
    
    plt.show()
# Out:
# 2020 and 2021

# %% [markdown]
# It is very clear the proportion of individuals who were cured increased substantially as we moved into 2021.
#
# This is a huge positive -- something worked that led to a reduced percentage of COVID cases leading to death. There could be many reasons -- social distancing, vaccinations, etc., but no matter the reason it is great to see.

# %% [markdown]
# <b>Reducing Dimensionality</b>
#
# The research paper used ~25 different features to reach their results.
#
# My first goal is to reduce the number of features while maintaining (or improving) the performance of the models. This will reduce the amount of computation and possibly also reduce overfitting caused by learning from less meaningful features.
#
# Going forward, we will only use the model we deemed to be the best (XGB, based on the lowest FN percentage).

# %%
#### evaluate the most important variables for the model
best_mod = xgb.XGBClassifier(colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=1000,
                                  subsample=0.6)

# %% [markdown]
# We first check the importance of each feature to see which we can remove from the dataset. Below is the output where you can find the importance of each feature for the XGB classifier.

# %%
def check_feature_importance(model, features, target):
    """Determine the most important feature for the given model from the given data"""
    transformer, oversampler = preprocessing_fns()

    pipeline = imblearn.pipeline.make_pipeline(transformer, oversampler, model)

    pipeline.fit(features, target)

    return pd.DataFrame(pipeline.steps[2][1].feature_importances_, pipeline.steps[0][1].get_feature_names_out())

# %%
pd.set_option("display.max_columns", None)    
check_feature_importance(xgb.XGBClassifier(), exp1_f_train, exp1_t_train).T
# Out:
#    onehotencoder__CriteriaConfirmation_Clinic  \
# 0                                    0.006323
#
#    onehotencoder__CriteriaConfirmation_Epidem.  \
# 0                                     0.012085
#
#    onehotencoder__CriteriaConfirmation_Lab  \
# 0                                 0.010882
#
#    onehotencoder__CriteriaConfirmation_N/A  onehotencoder__Sex_F  \
# 0                                      0.0              0.011631
#
#    onehotencoder__Sex_M  onehotencoder__Sex_N/A  \
# 0              0.006068                     0.0
#
#    onehotencoder__ColorRace_Black  onehotencoder__ColorRace_Brown  \
# 0                        0.006505                        0.005794
#
#    onehotencoder__ColorRace_Indigenous  onehotencoder__ColorRace_N/A  \
# 0                             0.002631                      0.010111
#
#    onehotencoder__ColorRace_White  onehotencoder__ColorRace_Yellow  \
# 0                        0.008653                         0.006246
#
#    onehotencoder__Education_Gr. 1  onehotencoder__Education_Gr. 4  \
# 0                        0.013866                        0.006998
#
#    onehotencoder__Education_HS  onehotencoder__Education_Higher Ed.  \
# 0                     0.015901                             0.020559
#
#    onehotencoder__Education_I Gr. 4  onehotencoder__Education_I Gr. 8  \
# 0                          0.007791                          0.008612
#
#    onehotencoder__Education_I HS  onehotencoder__Education_I Higher  \
# 0                       0.006583                           0.006527
#
#    onehotencoder__Education_N/A  onehotencoder__Education_None  \
# 0                      0.009316                       0.007142
#
#    onehotencoder__Fever_N/A  onehotencoder__Fever_No  \
# 0                   0.00391                 0.007237
#
#    onehotencoder__Fever_Yes  onehotencoder__BreathingDifficulty_N/A  \
# 0                  0.010719                                     0.0
#
#    onehotencoder__BreathingDifficulty_No  \
# 0                               0.005411
#
#    onehotencoder__BreathingDifficulty_Yes  onehotencoder__Cough_N/A  \
# 0                                0.074275                       0.0
#
#    onehotencoder__Cough_No  onehotencoder__Cough_Yes  \
# 0                 0.008893                  0.009642
#
#    onehotencoder__RunnyNose_N/A  onehotencoder__RunnyNose_No  \
# 0                      0.002053                     0.008254
#
#    onehotencoder__RunnyNose_Yes  onehotencoder__SoreThroat_N/A  \
# 0                      0.009847                       0.001355
#
#    onehotencoder__SoreThroat_No  onehotencoder__SoreThroat_Yes  \
# 0                      0.012771                       0.008157
#
#    onehotencoder__Diarrhea_N/A  onehotencoder__Diarrhea_No  \
# 0                     0.003689                    0.008472
#
#    onehotencoder__Diarrhea_Yes  onehotencoder__Headache_N/A  \
# 0                     0.011559                     0.004249
#
#    onehotencoder__Headache_No  onehotencoder__Headache_Yes  \
# 0                    0.011739                     0.025648
#
#    onehotencoder__ComorbidityPulmonary_N/A  \
# 0                                 0.000926
#
#    onehotencoder__ComorbidityPulmonary_No  \
# 0                                0.007196
#
#    onehotencoder__ComorbidityPulmonary_Yes  \
# 0                                 0.002478
#
#    onehotencoder__ComorbidityCardiac_N/A  \
# 0                               0.010556
#
#    onehotencoder__ComorbidityCardiac_No  \
# 0                              0.008374
#
#    onehotencoder__ComorbidityCardiac_Yes  onehotencoder__ComorbidityRenal_N/A  \
# 0                               0.005757                             0.002658
#
#    onehotencoder__ComorbidityRenal_No  onehotencoder__ComorbidityRenal_Yes  \
# 0                             0.00719                             0.018832
#
#    onehotencoder__ComorbidityDiabetes_N/A  \
# 0                                     0.0
#
#    onehotencoder__ComorbidityDiabetes_No  \
# 0                                0.01185
#
#    onehotencoder__ComorbidityDiabetes_Yes  \
# 0                                0.020885
#
#    onehotencoder__ComorbiditySmoking_N/A  \
# 0                                    0.0
#
#    onehotencoder__ComorbiditySmoking_No  \
# 0                               0.01672
#
#    onehotencoder__ComorbiditySmoking_Yes  \
# 0                               0.004143
#
#    onehotencoder__ComorbidityObesity_N/A  \
# 0                               0.008026
#
#    onehotencoder__ComorbidityObesity_No  \
# 0                              0.004407
#
#    onehotencoder__ComorbidityObesity_Yes  onehotencoder__Hospitalized_N/A  \
# 0                               0.009774                         0.009212
#
#    onehotencoder__Hospitalized_No  onehotencoder__Hospitalized_Yes  \
# 0                        0.006577                         0.110898
#
#    onehotencoder__TravelBrasil_N/A  onehotencoder__TravelBrasil_No  \
# 0                         0.009438                         0.00628
#
#    onehotencoder__TravelBrasil_Yes  onehotencoder__TravelInternational_N/A  \
# 0                         0.011453                                0.008063
#
#    onehotencoder__TravelInternational_No  \
# 0                               0.014708
#
#    onehotencoder__TravelInternational_Yes  onehotencoder__OverSixty_No  \
# 0                                0.005301                     0.217423
#
#    onehotencoder__OverSixty_Yes  ordinalencoder__AgeGroup  \
# 0                           0.0                  0.025385
#
#    ordinalencoder__SumComorbidities  ordinalencoder__SumSymptoms
# 0                          0.008984                     0.008403

# %% [markdown]
# From the above results, I will keep only the following features and remove the rest:
# - Hospitalization
# - Age Group
# - Over60
# - Sum of Symptoms
# - Sum of Comorbidities
# - Breathing Difficulty
# - Sore Throat
# - Headache
# - Education
#
# Then we will go through the same experimental process as before, but using a 'focused' dataset containing only the above features:

# %%
focused_exp1 = pr10_exp1_df.copy()
focused_exp2 = pr10_exp2_df.copy()
for df in focused_exp1, focused_exp2:
    df.drop(columns=['CriteriaConfirmation', 'Sex', 'ColorRace', 'Fever', 'Cough', 'RunnyNose', 'Diarrhea',
                     'ComorbidityPulmonary', 'ComorbidityCardiac', 'ComorbidityRenal',
                     'ComorbiditySmoking', 'ComorbidityObesity', 'TravelBrasil', 'TravelInternational'],
            inplace=True)

# %%
focused_f_train = focused_exp1.iloc[:, 1:]
focused_t_train = focused_exp1.iloc[:, 0]
focused_f_test = focused_exp2.iloc[:, 1:]
focused_t_test = focused_exp2.iloc[:, 0]

# %%
focused_dfs = run_exp([best_mod],
                      focused_f_train, focused_t_train, focused_f_test, focused_t_test,
                      evals=['accuracy', 'roc_auc', 'average_precision', 'precision', 'recall', 'f1'], rpt=1,
                      focused=True)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...) results done
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...) predicts done
# Round 1 completed

# %%
# Get means of test results for each run
focused_train_means, focused_test_means = lists_of_runs_to_lists_of_model_means(focused_dfs)

# %%
# create correct data format for confusion matrices
focused_models, focused_real_and_preds = create_confusion_matrix_info(focused_test_means)

# %% [markdown]
# Here we can see the confusion matrix using only the focused dataset and can compare it with the results of the previous classifiers.

# %%
# create confusion matrices
build_conf_mtrx_grid(focused_models, focused_real_and_preds,
                         filename='conf_mtrx_focused_test',
                         title='Confusion Matrices from Focused Test Data')

# %%
display(Image(filename=f'{figure_path}\\conf_mtrx_exp2_test.PNG'))

# %%
build_comparison_tables(focused_test_means)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>XGBClassifier</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Accuracy</td>
#       <td>0.863759</td>
#     </tr>
#     <tr>
#       <td>ROC AUC</td>
#       <td>0.865117</td>
#     </tr>
#     <tr>
#       <td>PR AUC</td>
#       <td>0.632421</td>
#     </tr>
#     <tr>
#       <td>Precision</td>
#       <td>0.295197</td>
#     </tr>
#     <tr>
#       <td>Recall</td>
#       <td>0.866667</td>
#     </tr>
#     <tr>
#       <td>F1</td>
#       <td>0.440391</td>
#     </tr>
#   </tbody>
# </table>

# %%
build_comparison_tables(exp2_test_means)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LogisticRegression</th>
#       <th>LinearDiscriminantAnalysis</th>
#       <th>KNeighborsClassifier</th>
#       <th>DecisionTreeClassifier</th>
#       <th>XGBClassifier</th>
#       <th>SVC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Accuracy</td>
#       <td>0.876923</td>
#       <td>0.877875</td>
#       <td>0.886281</td>
#       <td>0.834734</td>
#       <td>0.876606</td>
#       <td>0.860270</td>
#     </tr>
#     <tr>
#       <td>ROC AUC</td>
#       <td>0.875726</td>
#       <td>0.872640</td>
#       <td>0.825627</td>
#       <td>0.852043</td>
#       <td>0.880347</td>
#       <td>0.872837</td>
#     </tr>
#     <tr>
#       <td>PR AUC</td>
#       <td>0.644674</td>
#       <td>0.629329</td>
#       <td>0.369150</td>
#       <td>0.535101</td>
#       <td>0.660909</td>
#       <td>0.634538</td>
#     </tr>
#     <tr>
#       <td>Precision</td>
#       <td>0.319288</td>
#       <td>0.320076</td>
#       <td>0.321701</td>
#       <td>0.255255</td>
#       <td>0.320037</td>
#       <td>0.292477</td>
#     </tr>
#     <tr>
#       <td>Recall</td>
#       <td>0.874359</td>
#       <td>0.866667</td>
#       <td>0.756410</td>
#       <td>0.871795</td>
#       <td>0.884615</td>
#       <td>0.887179</td>
#     </tr>
#     <tr>
#       <td>F1</td>
#       <td>0.467764</td>
#       <td>0.467497</td>
#       <td>0.451415</td>
#       <td>0.394890</td>
#       <td>0.470027</td>
#       <td>0.439924</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Although the focused XGB performed slightly worse than the XGB with all 25 features, it had similar performance in all four quadrants of the confusion matrix.
#
# This dataset was great to work with because of the extensive amount of data for each observation. However, not all datasets are like this.
#
# It is now apparent that with only these key features, and likely even with a few less, we can obtain similar model effectiveness as if we had 25 or more.

# %% [markdown]
# <b>Predicting Eight Months Ahead and Training on More Data</b>
#
# The next goal is to use the most effective model from the previous experiments, and train it on all the Exp1+2 data (before June 2020). Then, I will test it on data from 2021 to evaluate model performance when looking 8+ months into the future after training on more data.

# %%
train_pre_2020_june = all_data[
    (all_data['NotificationDate'] < "2020-06-01")].copy()
test_recent = all_data[
    (all_data['NotificationDate'] > "2020-12-31")].copy()

for df in train_pre_2020_june, test_recent:
    del df['NotificationDate']
    
train_pre_2020_june_f = train_pre_2020_june.iloc[:, 1:]
train_pre_2020_june_t = train_pre_2020_june.iloc[:, 0]
test_recent_f = test_recent.iloc[:, 1:]
test_recent_t = test_recent.iloc[:, 0]

# %%
recent_dfs = run_exp([best_mod],
                     train_pre_2020_june_f,
                     train_pre_2020_june_t,
                     test_recent_f,
                     test_recent_t,
                     evals=['accuracy', 'roc_auc', 'average_precision', 'precision', 'recall', 'f1'],
                     rpt=1)

# Get means of test results for each run
train_pre_2020_june_means, test_recent_means = lists_of_runs_to_lists_of_model_means(recent_dfs)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...) results done
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...) predicts done
# Round 1 completed

# %%
# create correct data format for confusion matrices
recent_data_models, recent_data_real_and_preds = create_confusion_matrix_info(test_recent_means)

# create confusion matrices
build_conf_mtrx_grid(recent_data_models, recent_data_real_and_preds,
                         filename='conf_mtrx_recent_test',
                         title='Confusion Matrices from Recent Test Data')

# %%
display(Image(filename=f'{figure_path}\\conf_mtrx_exp2_test.PNG'))

# %%
build_comparison_tables(test_recent_means)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>XGBClassifier</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Accuracy</td>
#       <td>0.917609</td>
#     </tr>
#     <tr>
#       <td>ROC AUC</td>
#       <td>0.862135</td>
#     </tr>
#     <tr>
#       <td>PR AUC</td>
#       <td>0.475222</td>
#     </tr>
#     <tr>
#       <td>Precision</td>
#       <td>0.223658</td>
#     </tr>
#     <tr>
#       <td>Recall</td>
#       <td>0.803421</td>
#     </tr>
#     <tr>
#       <td>F1</td>
#       <td>0.349908</td>
#     </tr>
#   </tbody>
# </table>

# %%
build_comparison_tables(exp2_test_means)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LogisticRegression</th>
#       <th>LinearDiscriminantAnalysis</th>
#       <th>KNeighborsClassifier</th>
#       <th>DecisionTreeClassifier</th>
#       <th>XGBClassifier</th>
#       <th>SVC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Accuracy</td>
#       <td>0.876923</td>
#       <td>0.877875</td>
#       <td>0.886281</td>
#       <td>0.834734</td>
#       <td>0.876606</td>
#       <td>0.860270</td>
#     </tr>
#     <tr>
#       <td>ROC AUC</td>
#       <td>0.875726</td>
#       <td>0.872640</td>
#       <td>0.825627</td>
#       <td>0.852043</td>
#       <td>0.880347</td>
#       <td>0.872837</td>
#     </tr>
#     <tr>
#       <td>PR AUC</td>
#       <td>0.644674</td>
#       <td>0.629329</td>
#       <td>0.369150</td>
#       <td>0.535101</td>
#       <td>0.660909</td>
#       <td>0.634538</td>
#     </tr>
#     <tr>
#       <td>Precision</td>
#       <td>0.319288</td>
#       <td>0.320076</td>
#       <td>0.321701</td>
#       <td>0.255255</td>
#       <td>0.320037</td>
#       <td>0.292477</td>
#     </tr>
#     <tr>
#       <td>Recall</td>
#       <td>0.874359</td>
#       <td>0.866667</td>
#       <td>0.756410</td>
#       <td>0.871795</td>
#       <td>0.884615</td>
#       <td>0.887179</td>
#     </tr>
#     <tr>
#       <td>F1</td>
#       <td>0.467764</td>
#       <td>0.467497</td>
#       <td>0.451415</td>
#       <td>0.394890</td>
#       <td>0.470027</td>
#       <td>0.439924</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There are several factors to consider when looking at the results:
# 1) The proportion of cured cases to death cases went up substantially in the 2021 data. This leads to the model looking more effective because there are a higher percent of Cured cases to predict and fewer percent of Death cases.
# 2) The new model is trained on more data than before, which should inherently improve performance.
# 3) The new model is looking further into the future than any other experiment, which should be more difficult to do given how COVID and our processes changed over time.
#
# The confusion matrix from the new XGB classifier seems to indicate it is more effective, but the PR AUC, Precision, Recall, and F1 scores paint a substantially different story. The accuracy is higher not because of the improved effectiveness of the model, but because of the increase in cured cases to predict. If the model predicted every case as being cured it would have an accuracy around 95%, but wouldn't be a very helpful model.
#
# Based on the above information, it appears it is more difficult to predict 6-12 months into the future than it is to predict cases only a few weeks ahead. Thus, it would be important to continue training models over time to maintain effectiveness as new cases arise over time.

# %% [markdown]
# <b>Ensemble Learning</b>
#
# The last method to try and improve model performance is via ensemble learning with all the models. We will use a voting classifier to combine the predictions from each model.
#
# Setting the voting parameter to soft will allow us to average the certainty of each model for a given prediction instead of averaging the number of votes by each model. This will give more weight to the model predictions that are more certain.
#
# For example, one model with certainty of 100% cured / 0% death for an observation and two other models with certainty of 40% cured / 60% death would not lead to a 2-1 vote for death but a 60% certainty of being cured.

# %%
#### implement ensemble learning -- Voting Classifier -- with the 7 models from the paper
import sklearn.ensemble as sklen

voting = sklen.VotingClassifier(estimators=
                                [('LR', lm.LogisticRegression(max_iter=1500, C=3.0,
                                                              fit_intercept=True, tol=1e-05)),
                                 ('LDA', da.LinearDiscriminantAnalysis(store_covariance=True)),
                                 ('KNN', nbr.KNeighborsClassifier(algorithm='kd_tree', leaf_size=10,
                                                                  n_neighbors=10, p=1)),
                                 ('XGB', xgb.XGBClassifier(colsample_bytree=0.5, learning_rate=0.01, max_depth=3,
                                                           n_estimators=1000, subsample=0.6)),
                                 ('DT', tree.DecisionTreeClassifier(max_features=None, max_leaf_nodes=10,
                                                                    class_weight='balanced',
                                                                    criterion='log_loss', min_samples_leaf=3)),
                                 ('SVC', svm.SVC(kernel='rbf', C=10, gamma=0.0001, probability=True))],
                                voting='soft')

# %%
voting_dfs = run_exp([voting],
                     exp2_f_train,
                     exp2_t_train,
                     exp2_f_test,
                     exp2_t_test,
                     evals=['accuracy', 'roc_auc', 'average_precision', 'precision', 'recall', 'f1'],
                     rpt=1)

voting_train_means, voting_test_means = lists_of_runs_to_lists_of_model_means(voting_dfs)
# Out:
# VotingClassifier(estimators=[('LR',
#                               LogisticRegression(C=3.0, max_iter=1500,
#                                                  tol=1e-05)),
#                              ('LDA',
#                               LinearDiscriminantAnalysis(store_covariance=True)),
#                              ('KNN',
#                               KNeighborsClassifier(algorithm='kd_tree',
#                                                    leaf_size=10, n_neighbors=10,
#                                                    p=1)),
#                              ('XGB',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytr...
#                                             max_delta_step=None, max_depth=3,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             n_estimators=1000, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             predictor=None, random_state=None, ...)),
#                              ('DT',
#                               DecisionTreeClassifier(class_weight='balanced',
#                                                      criterion='log_loss',
#                                                      max_leaf_nodes=10,
#                                                      min_samples_leaf=3)),
#                              ('SVC',
#                               SVC(C=10, gamma=0.0001, probability=True))],
#                  voting='soft') results done
# VotingClassifier(estimators=[('LR',
#                               LogisticRegression(C=3.0, max_iter=1500,
#                                                  tol=1e-05)),
#                              ('LDA',
#                               LinearDiscriminantAnalysis(store_covariance=True)),
#                              ('KNN',
#                               KNeighborsClassifier(algorithm='kd_tree',
#                                                    leaf_size=10, n_neighbors=10,
#                                                    p=1)),
#                              ('XGB',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytr...
#                                             max_delta_step=None, max_depth=3,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             n_estimators=1000, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             predictor=None, random_state=None, ...)),
#                              ('DT',
#                               DecisionTreeClassifier(class_weight='balanced',
#                                                      criterion='log_loss',
#                                                      max_leaf_nodes=10,
#                                                      min_samples_leaf=3)),
#                              ('SVC',
#                               SVC(C=10, gamma=0.0001, probability=True))],
#                  voting='soft') predicts done
# Round 1 completed

# %%
# create correct data format for confusion matrices
voting_models, voting_real_and_preds = create_confusion_matrix_info(voting_test_means)

# create confusion matrices
build_conf_mtrx_grid(voting_models, voting_real_and_preds,
                         filename='conf_mtrx_voting_test',
                         title='Confusion Matrices from Voting Classifier on Exp2 Test Data')

# %%
display(Image(filename=f'{figure_path}\\conf_mtrx_exp2_test.PNG'))

# %%
build_comparison_tables(voting_test_means)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>VotingClassifier</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Accuracy</td>
#       <td>0.882474</td>
#     </tr>
#     <tr>
#       <td>ROC AUC</td>
#       <td>0.876289</td>
#     </tr>
#     <tr>
#       <td>PR AUC</td>
#       <td>0.630158</td>
#     </tr>
#     <tr>
#       <td>Precision</td>
#       <td>0.329446</td>
#     </tr>
#     <tr>
#       <td>Recall</td>
#       <td>0.869231</td>
#     </tr>
#     <tr>
#       <td>F1</td>
#       <td>0.477801</td>
#     </tr>
#   </tbody>
# </table>

# %%
build_comparison_tables(exp2_test_means)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LogisticRegression</th>
#       <th>LinearDiscriminantAnalysis</th>
#       <th>KNeighborsClassifier</th>
#       <th>DecisionTreeClassifier</th>
#       <th>XGBClassifier</th>
#       <th>SVC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Accuracy</td>
#       <td>0.876923</td>
#       <td>0.877875</td>
#       <td>0.886281</td>
#       <td>0.834734</td>
#       <td>0.876606</td>
#       <td>0.860270</td>
#     </tr>
#     <tr>
#       <td>ROC AUC</td>
#       <td>0.875726</td>
#       <td>0.872640</td>
#       <td>0.825627</td>
#       <td>0.852043</td>
#       <td>0.880347</td>
#       <td>0.872837</td>
#     </tr>
#     <tr>
#       <td>PR AUC</td>
#       <td>0.644674</td>
#       <td>0.629329</td>
#       <td>0.369150</td>
#       <td>0.535101</td>
#       <td>0.660909</td>
#       <td>0.634538</td>
#     </tr>
#     <tr>
#       <td>Precision</td>
#       <td>0.319288</td>
#       <td>0.320076</td>
#       <td>0.321701</td>
#       <td>0.255255</td>
#       <td>0.320037</td>
#       <td>0.292477</td>
#     </tr>
#     <tr>
#       <td>Recall</td>
#       <td>0.874359</td>
#       <td>0.866667</td>
#       <td>0.756410</td>
#       <td>0.871795</td>
#       <td>0.884615</td>
#       <td>0.887179</td>
#     </tr>
#     <tr>
#       <td>F1</td>
#       <td>0.467764</td>
#       <td>0.467497</td>
#       <td>0.451415</td>
#       <td>0.394890</td>
#       <td>0.470027</td>
#       <td>0.439924</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Unfortunately instead of creating a classifier that is more effective than the individuals, it seems to lie somewhere in the middle. It could be worth exploring if combining models that previously optimized for a certain metric (like using XGB and SVC to further reduce False Negative %) would create a stronger model by that same metric, but by using all models together we did not make any substantial improvements.

# %% [markdown]
# <b>Speed Improvements<b>
#
# Training, testing, building, and running the experiments took quite a while -- specifically, an extensive grid search (once for each model) and running Experiment 1 fully (33x) each needed to run overnight to complete.
#
# I researched solutions and stumbled upon a brilliant library -- sklearnex, built by and for Intel processors. A brief example of the speed performance is shown below and the absolute speed improvement increases with the size of the dataset and the number of repetitions.
#
# The time difference may not be apparent based on the device used to run this section. With my i7 processor, I saved (on average) ~35% of the time running an experiment with two repetitions using a Logistic Regression model. The time varies based on the model, and not all models are optimized (for example, XGBoost is not part of sklearn and therefore is not optimized).

# %%
# XGBoost isn't affected, so I will test using two repetitions of Logistic Regression
import time

patched_start = time.time()
run_exp([lm.LogisticRegression(max_iter=1500, C=2.0, fit_intercept=True, tol=1e-05)],
        train_pre_2020_june_f, train_pre_2020_june_t, test_recent_f, test_recent_t,
        evals=['accuracy', 'roc_auc', 'average_precision', 'precision', 'recall', 'f1'],
        rpt=1)
patched_end = time.time() - patched_start

print(patched_end)
# Out:
# LogisticRegression(C=2.0, max_iter=1500, tol=1e-05) results done
# LogisticRegression(C=2.0, max_iter=1500, tol=1e-05) predicts done
# Round 1 completed
# 82.77506279945374

# %%
sklearnex.unpatch_sklearn()
from sklearn.linear_model import LogisticRegression

unpatched_start = time.time()
run_exp([LogisticRegression(max_iter=1500, C=2.0, fit_intercept=True, tol=1e-05)],
        train_pre_2020_june_f, train_pre_2020_june_t, test_recent_f, test_recent_t,
        evals=['accuracy', 'roc_auc', 'average_precision', 'precision', 'recall', 'f1'],
        rpt=1)
unpatched_end = time.time() - unpatched_start

print(unpatched_end)
# Out:
# LogisticRegression(C=2.0, max_iter=1500, tol=1e-05) results done
# LogisticRegression(C=2.0, max_iter=1500, tol=1e-05) predicts done
# Round 1 completed
# 131.23385453224182

# %%
print(f'Train Data # of rows = {len(train_pre_2020_june_f.index)}\n'
      f'Test Data # of rows = {len(test_recent_f.index)}\n'
      f'Seconds Taken for Normal Sklearn Model: {unpatched_end}\n'
      f'Seconds Taken for Sklearnex Model: {patched_end}\n'
      f'% of Time Saved: {round((1-(patched_end / unpatched_end))*100)}%')
# Out:
# Train Data # of rows = 22344
# Test Data # of rows = 133449
# Seconds Taken for Normal Sklearn Model: 131.23385453224182
# Seconds Taken for Sklearnex Model: 82.77506279945374
# % of Time Saved: 37%

# %% [markdown]
# The difference in speed can only be demonstrated on Intel processors. If you want to see it in action but don't have an Intel processor, you can check out this video of me running the same functions locally.
#
# https://www.youtube.com/embed/kFsFhcGfpdI

# %% [markdown]
# And this marks the end of the notebook! If this has been helpful or if you have suggestions, feel free to send me your feedback as I'd love to hear it. If you dive deeper into any topics explored in this notebook and come upon something interesting, shoot me a message as I'd love to learn more.
